# %%
from commonTools import trakerManager
from plotnine import *
import datetime
import pandas as pd
import math
from mizani.breaks import date_breaks
from mizani.formatters import date_format

# %% [markdown]
# input your path to data

# %%
path_to_data = r'C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs'
#dont touch the model path
path_to_model = r'C:\Users\eddie\Documents\GitHub\wormLearn\models\20-03-19_08-08_retrain\trained_model.pth'
#file type? should be tif
file_type = '.tif'
timestamp_format = r'%M%S'
framerate = 2
#why is framerate two?

# %% [markdown]
# dont bother changing the path to the model!

# %%
MGMT.easy_group_maker(start=1, total=n_plates, pre='\\plate', n=5, post='\\')
#[f'\\plate{i}\\' for i in [3,4,5,6,12345]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/2105979152.py in <module>
# ----> 1 MGMT.easy_group_maker(start=1, total=n_plates, pre='\\plate', n=5, post='\\')
#       2 #[f'\\plate{i}\\' for i in [3,4,5,6,12345]]
#
# NameError: name 'n_plates' is not defined

# %%
MGMT = trakerManager.InferenceManager(path_to_data, path_to_model, file_type, timestamp_format)  
MGMT.read_data()

# n_plates = len(MGMT.experiments)
# n_plates = 20
# MGMT.calibration_dictionary({2952/49:   MGMT.easy_group_maker(start=1, total=n_plates, pre='\\plate', n=5, post='\\')[0],  ## rig1
#                              69/1:      MGMT.easy_group_maker(start=1, total=n_plates, pre='\\plate', n=5, post='\\')[1],  ## rig2
#                              2225/25.4: MGMT.easy_group_maker(start=1, total=n_plates, pre='\\plate', n=5, post='\\')[2],  ## rig3
#                              2087/25.4: MGMT.easy_group_maker(start=1, total=n_plates, pre='\\plate', n=5, post='\\')[3],  ## rig4
#                              1890/25.4: MGMT.easy_group_maker(start=1, total=n_plates, pre='\\plate', n=5, post='\\')[4]}) ## rig5
# Out:
# 25 .tif files found in C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate1\
# 25 .tif files found in C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate2\
# 25 .tif files found in C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate3\
# 25 .tif files found in C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate4\
# 25 .tif files found in C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate5\
# 25 .tif files found in C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate6\

# %%
## Infer the worm locations if you hadnt already
MGMT.infer_worm_BBoxes()
MGMT.save_as_PASCAL_VOC()
# Out:
# Loading model...
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to C:\Users\eddie/.cache\torch\hub\checkpoints\fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100.0%
# Infering on dataset C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate1\ ...
# Infering on dataset C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate2\ ...
# Infering on dataset C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate3\ ...
# Infering on dataset C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate4\ ...
# Infering on dataset C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate5\ ...
# Infering on dataset C:\Users\eddie\Documents\GitHub\wormLearn\figures\test_imgs\Plate6\ ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9716/607816134.py in <module>
#       1 ## Infer the worm locations if you hadnt already
# ----> 2 MGMT.infer_worm_BBoxes()
#       3 MGMT.save_as_PASCAL_VOC()
#
# ~\Documents\GitHub\wormLearn\commonTools\trakerManager.py in infer_worm_BBoxes(self)
#      49     def infer_worm_BBoxes(self):
#      50         self._infer_worm_BBoxes()
# ---> 51         self.organize_inference_results()
#      52
#      53     def _infer_worm_BBoxes(self):
#
# ~\Documents\GitHub\wormLearn\commonTools\trakerManager.py in organize_inference_results(self)
#      90
#      91     def organize_inference_results(self):
# ---> 92         [experiment.organize_inference_results(self.ts_fmt) for experiment in self.experiments]
#      93
#      94     def track_worms(self, pixels_per_mm=None, framerate=2, missing_frames_forgiven=0, max_mm_per_s=2, frame_window=None):
#
# ~\Documents\GitHub\wormLearn\commonTools\trakerManager.py in <listcomp>(.0)
#      90
#      91     def organize_inference_results(self):
# ---> 92         [experiment.organize_inference_results(self.ts_fmt) for experiment in self.experiments]
#      93
#      94     def track_worms(self, pixels_per_mm=None, framerate=2, missing_frames_forgiven=0, max_mm_per_s=2, frame_window=None):
#
# ~\Documents\GitHub\wormLearn\commonTools\trakerManager.py in organize_inference_results(self, ts_fmt, min_score)
#     367             timestamp_from_name = re.findall(regex_overlappable, name_no_serial)[-1]
#     368             tp = datetime.datetime.strptime(timestamp_from_name, ts_fmt).strftime('%d:%H:%M:%S')
# --> 369             self.result_to_timepoint(tp, img_N, img, result, min_score)
#     370         print('Organized '+str(len(self.inference_results))+' results into '+str(len(self.timepoints))+' timepoints.')
#     371
#
# ~\Documents\GitHub\wormLearn\commonTools\trakerManager.py in result_to_timepoint(self, timepoint, n, img, result, min_score)
#     376         if timepoint not in self.timepoints:
#     377             self.timepoints[timepoint] = Timepoint()
# --> 378         self.timepoints[timepoint].add_result(n, img, result, min_score=min_score)
#     379
#     380     def track_worms_within_timepoints(self, pixels_per_mm=None, framerate=2, missing_frames_forgiven=0, max_mm_per_s=2, frame_window=None):
#
# ~\Documents\GitHub\wormLearn\commonTools\trakerManager.py in add_result(self, n, img, result, min_score)
#     664
#     665     def add_result(self, n, img, result, min_score=0.9):
# --> 666         n = int(n)
#     667         scores = result['scores']
#     668         for cat in result:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
## or load the inferences if they existed already
MGMT.load_inferences_from_xml()

# %%
MGMT.track_worms(framerate=framerate, missing_frames_forgiven=2, max_mm_per_s=1)

# %% [markdown]
# **speed tracker**

# %%
MGMT.mean_speeds_by_group( MGMT.easy_group_maker(start=1, total=n_plates, pre='\\plate', n=4, post='\\'), ['a', 'b', 'c', 'd'], framerate=framerate )

# %% [markdown]
# **Rose plot dialogue**

# %%
#MGMT.experiments[0].timepoints['01:00:00:00'].list_of_worms[0].coords
#make first frame 0,0 by subtracting the x and y. do to processive frames to get origin based data
#rotional transformation to get real 'rose' plot. 

MGMT.track_worms_all_experiments.list_of_worms(track_across_timepoints=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20128/454654142.py in <module>
#       3 #rotional transformation to get real 'rose' plot.
#       4
# ----> 5 MGMT.track_worms_across_timepoints.list_of_worms[0]
#
# NameError: name 'MGMT' is not defined

# %% [markdown]
# **paralysis analysis**

# %%
group_names = ['RB','NJ','JCC','N2']

# paralysis_by_group, SEM_by_group = 
aldicarb_results = MGMT.paralysis_by_group(groups= MGMT.easy_group_maker(start=1, total=n_plates, pre='\\plate', n=4, post='\\'), group_names=group_names, max_mm_movement=0.15)

print(aldicarb_results)
aldicarb_results.to_csv(path_to_data+'\\my_results.csv')
# Out:
#                   time strain      mean       sem
# 0  1900-01-01 00:00:00     RB  0.000000  0.000000
# 1  1900-01-01 00:10:00     RB  0.022222  0.017213
# 2  1900-01-01 00:20:00     RB  0.023810  0.018443
# 3  1900-01-01 00:30:00     RB  0.025641  0.019861
# 4  1900-01-01 00:40:00     RB  0.111888  0.027084
# ..                 ...    ...       ...       ...
# 71 1900-01-01 02:20:00     N2  0.940476  0.041921
# 72 1900-01-01 02:30:00     N2  0.885065  0.033270
# 73 1900-01-01 02:40:00     N2  0.889827  0.026271
# 74 1900-01-01 02:50:00     N2  0.923810  0.022775
# 75 1900-01-01 03:00:00     N2       NaN       NaN
#
# [76 rows x 4 columns]

# %%
(ggplot(aldicarb_results, aes(x='time', y='mean', color='strain')) +
geom_line())
# Out:
# C:\Users\ohbar\anaconda3\envs\wormLearn\lib\site-packages\plotnine\geoms\geom_path.py:75: PlotnineWarning: geom_path: Removed 1 rows containing missing values.
# <ggplot: (121337229505)>
